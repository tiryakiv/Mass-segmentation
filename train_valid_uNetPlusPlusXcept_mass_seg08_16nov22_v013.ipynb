# %%
from model_uNetPlusPlusXception import *
from data import *
import os, os.path

vid="v013_5" #version id should match the file number. Last number shows the cross-validation fold number
# Ran on DellWS with GeForce RTX3060 GPU

# Count the number of train and valid files
train_dir = 'mass_seg_08/train0'+vid[-1]+'/mg'
train_count=len([name for name in os.listdir(train_dir) if os.path.isfile(os.path.join(train_dir, name))])

valid_dir = 'mass_seg_08/valid0'+vid[-1]+'/mg'
valid_count=len([name for name in os.listdir(valid_dir) if os.path.isfile(os.path.join(valid_dir, name))])

# %% [markdown]
# ### Train with data generator

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger

#Data augmentation
data_gen_args = dict(rotation_range=90,
                    width_shift_range=0.2,
                    height_shift_range=0.2,
                    shear_range=0.2,
                    zoom_range=0.2,
                    horizontal_flip=True,
                    vertical_flip=True,
                    fill_mode='wrap')

# SETTINGS ***
batch_size=2
learning_rate=1e-4

train_gen = trainGenerator(batch_size,'mass_seg_08/train0'+vid[-1],'mg','mask',data_gen_args,save_to_dir = None)
valid_gen = trainGenerator(batch_size,'mass_seg_08/valid0'+vid[-1],'mg','mask',data_gen_args,save_to_dir = None)

# train_count images are used for training, valid_count images for validating
train_steps = train_count//batch_size
valid_steps = valid_count//batch_size

# SETTINGS ***
loss = dice_loss
steps_per_epoch = 3*train_steps
num_epochs = 100

model = uNetPlusPlusXception(num_top_filter=12, deep_supervision = False)

opt = tf.keras.optimizers.Adam(learning_rate)
metrics = ["acc", dice_coef]
model.compile(loss=loss, optimizer=opt, metrics=metrics)

callbacks = [
             ModelCheckpoint('files_mass_seg_xval/unet_mass_seg_'+vid+'.hdf5', verbose=1, save_best_model=True),
             ReduceLROnPlateau(monitor="val_loss", patience=3, factor=0.1, verbose=1, min_lr=1e-8),
             CSVLogger("files_mass_seg_xval/data_"+vid+".csv"),
             EarlyStopping(monitor="val_loss", patience=5, verbose=1)
            ]

model.fit(train_gen, validation_data=valid_gen, steps_per_epoch=steps_per_epoch, validation_steps=valid_steps, 
                    epochs=num_epochs, callbacks=callbacks)
# Out:
# Found 283 images belonging to 1 classes.
# Found 283 images belonging to 1 classes.
# Epoch 1/100
# 423/423 [==============================] - ETA: 0s - loss: 0.9352 - acc: 0.6227 - dice_coef: 0.0648Found 69 images belonging to 1 classes.
# Found 69 images belonging to 1 classes.
#
# Epoch 1: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 288s 618ms/step - loss: 0.9352 - acc: 0.6227 - dice_coef: 0.0648 - val_loss: 0.8816 - val_acc: 0.8528 - val_dice_coef: 0.1184 - lr: 1.0000e-04
# Epoch 2/100
# 423/423 [==============================] - ETA: 0s - loss: 0.9114 - acc: 0.7787 - dice_coef: 0.0885
# Epoch 2: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 254s 600ms/step - loss: 0.9114 - acc: 0.7787 - dice_coef: 0.0885 - val_loss: 0.8552 - val_acc: 0.8581 - val_dice_coef: 0.1448 - lr: 1.0000e-04
# Epoch 3/100
# 423/423 [==============================] - ETA: 0s - loss: 0.8869 - acc: 0.8505 - dice_coef: 0.1135
# Epoch 3: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 255s 602ms/step - loss: 0.8869 - acc: 0.8505 - dice_coef: 0.1135 - val_loss: 0.8138 - val_acc: 0.9107 - val_dice_coef: 0.1862 - lr: 1.0000e-04
# Epoch 4/100
# 423/423 [==============================] - ETA: 0s - loss: 0.8599 - acc: 0.8890 - dice_coef: 0.1400
# Epoch 4: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 255s 602ms/step - loss: 0.8599 - acc: 0.8890 - dice_coef: 0.1400 - val_loss: 0.7586 - val_acc: 0.9340 - val_dice_coef: 0.2414 - lr: 1.0000e-04
# Epoch 5/100
# 423/423 [==============================] - ETA: 0s - loss: 0.8275 - acc: 0.9163 - dice_coef: 0.1722
# Epoch 5: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 256s 604ms/step - loss: 0.8275 - acc: 0.9163 - dice_coef: 0.1722 - val_loss: 0.7487 - val_acc: 0.9435 - val_dice_coef: 0.2513 - lr: 1.0000e-04
# Epoch 6/100
# 423/423 [==============================] - ETA: 0s - loss: 0.7954 - acc: 0.9350 - dice_coef: 0.2041
# Epoch 6: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 255s 602ms/step - loss: 0.7954 - acc: 0.9350 - dice_coef: 0.2041 - val_loss: 0.7427 - val_acc: 0.9451 - val_dice_coef: 0.2573 - lr: 1.0000e-04
# Epoch 7/100
# 423/423 [==============================] - ETA: 0s - loss: 0.7571 - acc: 0.9506 - dice_coef: 0.2431
# Epoch 7: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 254s 601ms/step - loss: 0.7571 - acc: 0.9506 - dice_coef: 0.2431 - val_loss: 0.6990 - val_acc: 0.9727 - val_dice_coef: 0.3010 - lr: 1.0000e-04
# Epoch 8/100
# 423/423 [==============================] - ETA: 0s - loss: 0.6902 - acc: 0.9680 - dice_coef: 0.3103
# Epoch 8: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 252s 596ms/step - loss: 0.6902 - acc: 0.9680 - dice_coef: 0.3103 - val_loss: 0.6726 - val_acc: 0.9847 - val_dice_coef: 0.3274 - lr: 1.0000e-04
# Epoch 9/100
# 423/423 [==============================] - ETA: 0s - loss: 0.6338 - acc: 0.9768 - dice_coef: 0.3659
# Epoch 9: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 255s 603ms/step - loss: 0.6338 - acc: 0.9768 - dice_coef: 0.3659 - val_loss: 0.6502 - val_acc: 0.9824 - val_dice_coef: 0.3498 - lr: 1.0000e-04
# Epoch 10/100
# 423/423 [==============================] - ETA: 0s - loss: 0.5741 - acc: 0.9833 - dice_coef: 0.4266
# Epoch 10: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 256s 604ms/step - loss: 0.5741 - acc: 0.9833 - dice_coef: 0.4266 - val_loss: 0.5917 - val_acc: 0.9858 - val_dice_coef: 0.4083 - lr: 1.0000e-04
# Epoch 11/100
# 423/423 [==============================] - ETA: 0s - loss: 0.4945 - acc: 0.9857 - dice_coef: 0.5054
# Epoch 11: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 256s 606ms/step - loss: 0.4945 - acc: 0.9857 - dice_coef: 0.5054 - val_loss: 0.5459 - val_acc: 0.9861 - val_dice_coef: 0.4541 - lr: 1.0000e-04
# Epoch 12/100
# 423/423 [==============================] - ETA: 0s - loss: 0.4826 - acc: 0.9867 - dice_coef: 0.5175
# Epoch 12: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 255s 601ms/step - loss: 0.4826 - acc: 0.9867 - dice_coef: 0.5175 - val_loss: 0.4835 - val_acc: 0.9892 - val_dice_coef: 0.5165 - lr: 1.0000e-04
# Epoch 13/100
# 423/423 [==============================] - ETA: 0s - loss: 0.4176 - acc: 0.9882 - dice_coef: 0.5822
# Epoch 13: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 256s 603ms/step - loss: 0.4176 - acc: 0.9882 - dice_coef: 0.5822 - val_loss: 0.4903 - val_acc: 0.9870 - val_dice_coef: 0.5097 - lr: 1.0000e-04
# Epoch 14/100
# 423/423 [==============================] - ETA: 0s - loss: 0.3959 - acc: 0.9888 - dice_coef: 0.6038
# Epoch 14: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 255s 602ms/step - loss: 0.3959 - acc: 0.9888 - dice_coef: 0.6038 - val_loss: 0.4202 - val_acc: 0.9895 - val_dice_coef: 0.5798 - lr: 1.0000e-04
# Epoch 15/100
# 423/423 [==============================] - ETA: 0s - loss: 0.3947 - acc: 0.9885 - dice_coef: 0.6054
# Epoch 15: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 254s 599ms/step - loss: 0.3947 - acc: 0.9885 - dice_coef: 0.6054 - val_loss: 0.4516 - val_acc: 0.9881 - val_dice_coef: 0.5484 - lr: 1.0000e-04
# Epoch 16/100
# 423/423 [==============================] - ETA: 0s - loss: 0.3846 - acc: 0.9892 - dice_coef: 0.6152
# Epoch 16: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 255s 602ms/step - loss: 0.3846 - acc: 0.9892 - dice_coef: 0.6152 - val_loss: 0.4618 - val_acc: 0.9872 - val_dice_coef: 0.5382 - lr: 1.0000e-04
# Epoch 17/100
# 423/423 [==============================] - ETA: 0s - loss: 0.3513 - acc: 0.9907 - dice_coef: 0.6483
# Epoch 17: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 423/423 [==============================] - 255s 603ms/step - loss: 0.3513 - acc: 0.9907 - dice_coef: 0.6483 - val_loss: 0.4398 - val_acc: 0.9885 - val_dice_coef: 0.5602 - lr: 1.0000e-04
# Epoch 18/100
# 423/423 [==============================] - ETA: 0s - loss: 0.3275 - acc: 0.9905 - dice_coef: 0.6714
# Epoch 18: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 255s 602ms/step - loss: 0.3275 - acc: 0.9905 - dice_coef: 0.6714 - val_loss: 0.4760 - val_acc: 0.9885 - val_dice_coef: 0.5240 - lr: 1.0000e-05
# Epoch 19/100
# 423/423 [==============================] - ETA: 0s - loss: 0.3095 - acc: 0.9910 - dice_coef: 0.6910
# Epoch 19: saving model to files_mass_seg_xval\unet_mass_seg_v013_5.hdf5
# 423/423 [==============================] - 254s 601ms/step - loss: 0.3095 - acc: 0.9910 - dice_coef: 0.6910 - val_loss: 0.4372 - val_acc: 0.9885 - val_dice_coef: 0.5628 - lr: 1.0000e-05
# Epoch 19: early stopping

# %% [markdown]
# ### validate your model and save predicted results

# %%
validGene = testGenerator("files_cbis_mass_seg_trainval/valid/pred",valid_count)
model.load_weights("files_cbis_mass_seg_trainval/unet_mass_seg_"+vid+".hdf5")
results = model.predict(validGene,valid_count,verbose=1)
saveResult("files_cbis_mass_seg_trainval/valid/pred",results,vid[:4])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 640, 640, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 319, 319, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 319, 319, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 319, 319, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 317, 317, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 317, 317, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 317, 317, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 317, 317, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 317, 317, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 317, 317, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 317, 317, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 317, 317, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 159, 159, 12  8192        ['block1_conv2_act[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 159, 159, 12  0           ['block2_sepconv2_bn[0][0]']
#                                 8)
#
#  batch_normalization (BatchNorm  (None, 159, 159, 12  512        ['conv2d[0][0]']
#  alization)                     8)
#
#  add (Add)                      (None, 159, 159, 12  0           ['block2_pool[0][0]',
#                                 8)                                'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 159, 159, 12  0          ['add[0][0]']
#  n)                             8)
#
#  block3_sepconv1 (SeparableConv  (None, 159, 159, 25  33920      ['block3_sepconv1_act[0][0]']
#  2D)                            6)
#
#  block3_sepconv1_bn (BatchNorma  (None, 159, 159, 25  1024       ['block3_sepconv1[0][0]']
#  lization)                      6)
#
#  block3_sepconv2_act (Activatio  (None, 159, 159, 25  0          ['block3_sepconv1_bn[0][0]']
#  n)                             6)
#
#  block3_sepconv2 (SeparableConv  (None, 159, 159, 25  67840      ['block3_sepconv2_act[0][0]']
#  2D)                            6)
#
#  block3_sepconv2_bn (BatchNorma  (None, 159, 159, 25  1024       ['block3_sepconv2[0][0]']
#  lization)                      6)
#
#  conv2d_1 (Conv2D)              (None, 80, 80, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 80, 80, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 80, 80, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 80, 80, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 80, 80, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 80, 80, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 80, 80, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 80, 80, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 80, 80, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 80, 80, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 40, 40, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 40, 40, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 40, 40, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 40, 40, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 40, 40, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 40, 40, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 40, 40, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 40, 40, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 40, 40, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 40, 40, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 40, 40, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 40, 40, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 40, 40, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 40, 40, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 40, 40, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 40, 40, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 40, 40, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 40, 40, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 40, 40, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 40, 40, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 40, 40, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 40, 40, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 40, 40, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 40, 40, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 40, 40, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 40, 40, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 40, 40, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 40, 40, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 40, 40, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 40, 40, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 40, 40, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 40, 40, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 40, 40, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 40, 40, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 40, 40, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 40, 40, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 40, 40, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 40, 40, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 40, 40, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 40, 40, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 40, 40, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 40, 40, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 40, 40, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 40, 40, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 40, 40, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 40, 40, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 40, 40, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 40, 40, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 40, 40, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 40, 40, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 40, 40, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 40, 40, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 40, 40, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 40, 40, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 40, 40, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 40, 40, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 40, 40, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 40, 40, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 40, 40, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 40, 40, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 40, 40, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 40, 40, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 40, 40, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 40, 40, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 40, 40, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#  block12_sepconv2_bn (BatchNorm  (None, 40, 40, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 40, 40, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 40, 40, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 40, 40, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 40, 40, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 40, 40, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 40, 40, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 40, 40, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 40, 40, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 40, 40, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 40, 40, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  up42 (Conv2DTranspose)         (None, 80, 80, 96)   393312      ['block13_sepconv2_bn[0][0]']
#
#  merge42 (Concatenate)          (None, 80, 80, 824)  0           ['up42[0][0]',
#                                                                   'block4_sepconv2_bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 160, 160, 25  0          ['block3_sepconv2_bn[0][0]']
#  D)                             6)
#
#  up32 (Conv2DTranspose)         (None, 160, 160, 48  139824      ['block4_sepconv2_bn[0][0]']
#                                 )
#
#  conv42_1 (Conv2D)              (None, 80, 80, 96)   712032      ['merge42[0][0]']
#
#  merge32 (Concatenate)          (None, 160, 160, 30  0           ['up32[0][0]',
#                                 4)                                'zero_padding2d_1[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 320, 320, 12  0          ['block2_sepconv2_bn[0][0]']
#                                 8)
#
#  up22 (Conv2DTranspose)         (None, 320, 320, 24  24600       ['zero_padding2d_1[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 80, 80, 96)  384         ['conv42_1[0][0]']
#  ormalization)
#
#  conv32_1 (Conv2D)              (None, 160, 160, 48  131376      ['merge32[0][0]']
#                                 )
#
#  merge22 (Concatenate)          (None, 320, 320, 15  0           ['up22[0][0]',
#                                 2)                                'zero_padding2d[0][0]']
#
#  up12 (Conv2DTranspose)         (None, 640, 640, 12  6156        ['zero_padding2d[0][0]']
#                                 )
#
#  dp42_1 (Dropout)               (None, 80, 80, 96)   0           ['batch_normalization_16[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 160, 160, 48  192        ['conv32_1[0][0]']
#  ormalization)                  )
#
#  conv22_1 (Conv2D)              (None, 320, 320, 24  32856       ['merge22[0][0]']
#                                 )
#
#  merge12 (Concatenate)          (None, 640, 640, 15  0           ['up12[0][0]',
#                                 )                                 'input_1[0][0]']
#
#  conv42_2 (Conv2D)              (None, 80, 80, 96)   83040       ['dp42_1[0][0]']
#
#  dp32_1 (Dropout)               (None, 160, 160, 48  0           ['batch_normalization_10[0][0]']
#                                 )
#  batch_normalization_6 (BatchNo  (None, 320, 320, 24  96         ['conv22_1[0][0]']
#  rmalization)                   )
#
#  conv12_1 (Conv2D)              (None, 640, 640, 12  1632        ['merge12[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 80, 80, 96)  384         ['conv42_2[0][0]']
#  ormalization)
#
#  conv32_2 (Conv2D)              (None, 160, 160, 48  20784       ['dp32_1[0][0]']
#                                 )
#
#  dp22_1 (Dropout)               (None, 320, 320, 24  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 640, 640, 12  48         ['conv12_1[0][0]']
#  rmalization)                   )
#
#  dp42_2 (Dropout)               (None, 80, 80, 96)   0           ['batch_normalization_17[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 160, 160, 48  192        ['conv32_2[0][0]']
#  ormalization)                  )
#
#  conv22_2 (Conv2D)              (None, 320, 320, 24  5208        ['dp22_1[0][0]']
#                                 )
#
#  dp12_1 (Dropout)               (None, 640, 640, 12  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  up33 (Conv2DTranspose)         (None, 160, 160, 48  18480       ['dp42_2[0][0]']
#                                 )
#
#  dp32_2 (Dropout)               (None, 160, 160, 48  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 320, 320, 24  96         ['conv22_2[0][0]']
#  rmalization)                   )
#
#  conv12_2 (Conv2D)              (None, 640, 640, 12  1308        ['dp12_1[0][0]']
#                                 )
#
#  merge33 (Concatenate)          (None, 160, 160, 35  0           ['up33[0][0]',
#                                 2)                                'zero_padding2d_1[0][0]',
#                                                                   'dp32_2[0][0]']
#
#  dp22_2 (Dropout)               (None, 320, 320, 24  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  up23 (Conv2DTranspose)         (None, 320, 320, 24  4632        ['dp32_2[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 640, 640, 12  48         ['conv12_2[0][0]']
#  rmalization)                   )
#
#  conv33_1 (Conv2D)              (None, 160, 160, 48  152112      ['merge33[0][0]']
#                                 )
#
#  merge23 (Concatenate)          (None, 320, 320, 17  0           ['up23[0][0]',
#                                 6)                                'zero_padding2d[0][0]',
#                                                                   'dp22_2[0][0]']
#
#  dp12_2 (Dropout)               (None, 640, 640, 12  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  up13 (Conv2DTranspose)         (None, 640, 640, 12  1164        ['dp22_2[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 160, 160, 48  192        ['conv33_1[0][0]']
#  ormalization)                  )
#
#  conv23_1 (Conv2D)              (None, 320, 320, 24  38040       ['merge23[0][0]']
#                                 )
#
#  merge13 (Concatenate)          (None, 640, 640, 27  0           ['up13[0][0]',
#                                 )                                 'input_1[0][0]',
#                                                                   'dp12_2[0][0]']
#
#  dp33_1 (Dropout)               (None, 160, 160, 48  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 320, 320, 24  96         ['conv23_1[0][0]']
#  ormalization)                  )
#  conv13_1 (Conv2D)              (None, 640, 640, 12  2928        ['merge13[0][0]']
#                                 )
#
#  conv33_2 (Conv2D)              (None, 160, 160, 48  20784       ['dp33_1[0][0]']
#                                 )
#
#  dp23_1 (Dropout)               (None, 320, 320, 24  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 640, 640, 12  48         ['conv13_1[0][0]']
#  rmalization)                   )
#
#  batch_normalization_19 (BatchN  (None, 160, 160, 48  192        ['conv33_2[0][0]']
#  ormalization)                  )
#
#  conv23_2 (Conv2D)              (None, 320, 320, 24  5208        ['dp23_1[0][0]']
#                                 )
#
#  dp13_1 (Dropout)               (None, 640, 640, 12  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  dp33_2 (Dropout)               (None, 160, 160, 48  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 320, 320, 24  96         ['conv23_2[0][0]']
#  ormalization)                  )
#
#  conv13_2 (Conv2D)              (None, 640, 640, 12  1308        ['dp13_1[0][0]']
#                                 )
#
#  up24 (Conv2DTranspose)         (None, 320, 320, 24  4632        ['dp33_2[0][0]']
#                                 )
#
#  dp23_2 (Dropout)               (None, 320, 320, 24  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 640, 640, 12  48         ['conv13_2[0][0]']
#  rmalization)                   )
#
#  merge24 (Concatenate)          (None, 320, 320, 20  0           ['up24[0][0]',
#                                 0)                                'zero_padding2d[0][0]',
#                                                                   'dp22_2[0][0]',
#                                                                   'dp23_2[0][0]']
#
#  dp13_2 (Dropout)               (None, 640, 640, 12  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  up14 (Conv2DTranspose)         (None, 640, 640, 12  1164        ['dp23_2[0][0]']
#                                 )
#
#  conv24_1 (Conv2D)              (None, 320, 320, 24  43224       ['merge24[0][0]']
#                                 )
#
#  merge14 (Concatenate)          (None, 640, 640, 39  0           ['up14[0][0]',
#                                 )                                 'input_1[0][0]',
#                                                                   'dp12_2[0][0]',
#                                                                   'dp13_2[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 320, 320, 24  96         ['conv24_1[0][0]']
#  ormalization)                  )
#
#  conv14_1 (Conv2D)              (None, 640, 640, 12  4224        ['merge14[0][0]']
#                                 )
#
#  dp24_1 (Dropout)               (None, 320, 320, 24  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 640, 640, 12  48         ['conv14_1[0][0]']
#  ormalization)                  )
#
#  conv24_2 (Conv2D)              (None, 320, 320, 24  5208        ['dp24_1[0][0]']
#                                 )
#
#  dp14_1 (Dropout)               (None, 640, 640, 12  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 320, 320, 24  96         ['conv24_2[0][0]']
#  ormalization)                  )
#
#  conv14_2 (Conv2D)              (None, 640, 640, 12  1308        ['dp14_1[0][0]']
#                                 )
#
#  dp24_2 (Dropout)               (None, 320, 320, 24  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 640, 640, 12  48         ['conv14_2[0][0]']
#  ormalization)                  )
#
#  up15 (Conv2DTranspose)         (None, 640, 640, 12  1164        ['dp24_2[0][0]']
#                                 )
#
#  dp14_2 (Dropout)               (None, 640, 640, 12  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  merge15 (Concatenate)          (None, 640, 640, 51  0           ['up15[0][0]',
#                                 )                                 'input_1[0][0]',
#                                                                   'dp12_2[0][0]',
#                                                                   'dp13_2[0][0]',
#                                                                   'dp14_2[0][0]']
#
#  conv15_1 (Conv2D)              (None, 640, 640, 12  5520        ['merge15[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 640, 640, 12  48         ['conv15_1[0][0]']
#  ormalization)                  )
#
#  dp15_1 (Dropout)               (None, 640, 640, 12  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  conv15_2 (Conv2D)              (None, 640, 640, 12  1308        ['dp15_1[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 640, 640, 12  48         ['conv15_2[0][0]']
#  ormalization)                  )
#
#  dp15_2 (Dropout)               (None, 640, 640, 12  0           ['batch_normalization_23[0][0]']
#                                 )
#
#  output_4 (Conv2D)              (None, 640, 640, 1)  13          ['dp15_2[0][0]']
#
# ==================================================================================================
# Total params: 17,222,989
# Trainable params: 17,176,429
# Non-trainable params: 46,560
# __________________________________________________________________________________________________
