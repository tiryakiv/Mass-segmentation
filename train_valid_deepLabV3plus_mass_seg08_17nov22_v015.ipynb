# %%
from model_deepLabV3plus import *
from data import *
import os, os.path

vid="v015_5" #version id should match the file number. Last number shows the cross-validation fold number
# Ran on DellWS with GeForce RTX3060 GPU

# Count the number of train and valid files
train_dir = 'mass_seg_08/train0'+vid[-1]+'/mg'
train_count=len([name for name in os.listdir(train_dir) if os.path.isfile(os.path.join(train_dir, name))])

valid_dir = 'mass_seg_08/valid0'+vid[-1]+'/mg'
valid_count=len([name for name in os.listdir(valid_dir) if os.path.isfile(os.path.join(valid_dir, name))])

# %% [markdown]
# ### Train with data generator

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger

#Data augmentation
data_gen_args = dict(rotation_range=90,
                    width_shift_range=0.2,
                    height_shift_range=0.2,
                    shear_range=0.2,
                    zoom_range=0.2,
                    #brightness_range=[0.9,1.1],
                    horizontal_flip=True,
                    vertical_flip=True,
                    fill_mode='wrap')

# SETTINGS ***
batch_size=2
learning_rate=1e-4

train_gen = trainGenerator(batch_size,'mass_seg_08/train0'+vid[-1],'mg','mask',data_gen_args,save_to_dir = None)
valid_gen = trainGenerator(batch_size,'mass_seg_08/valid0'+vid[-1],'mg','mask',data_gen_args,save_to_dir = None)

# train_count images are used for training, valid_count images for validating
train_steps = train_count//batch_size
valid_steps = valid_count//batch_size

# SETTINGS ***
loss=dice_loss
steps_per_epoch=3*train_steps
num_epochs=100

model = deeplabv3_plus((640,640,3))

opt = tf.keras.optimizers.Adam(learning_rate)
metrics = ["acc", dice_coef, iou]
model.compile(loss=loss, optimizer=opt, metrics=metrics)

callbacks = [
             ModelCheckpoint('files_mass_seg_xval/unet_mass_seg_'+vid+'.hdf5', verbose=1, save_best_model=True),
             ReduceLROnPlateau(monitor="val_loss", patience=3, factor=0.1, verbose=1, min_lr=1e-8),
             CSVLogger("files_mass_seg_xval/data_"+vid+".csv"),
             EarlyStopping(monitor="val_loss", patience=5, verbose=1)
            ]

model.fit(train_gen, validation_data=valid_gen, steps_per_epoch=steps_per_epoch, validation_steps=valid_steps, 
                    epochs=num_epochs, callbacks=callbacks)
# Out:
# Found 283 images belonging to 1 classes.
# Found 283 images belonging to 1 classes.
# Epoch 1/100
# 423/423 [==============================] - ETA: 0s - loss: 0.7637 - acc: 0.9270 - dice_coef: 0.2361 - iou: 0.1486Found 69 images belonging to 1 classes.
# Found 69 images belonging to 1 classes.
#
# Epoch 1: saving model to files_mass_seg_xval\unet_mass_seg_v015_5.hdf5
# 423/423 [==============================] - 205s 403ms/step - loss: 0.7637 - acc: 0.9270 - dice_coef: 0.2361 - iou: 0.1486 - val_loss: nan - val_acc: 0.9817 - val_dice_coef: nan - val_iou: nan - lr: 1.0000e-04
# Epoch 2/100
# 423/423 [==============================] - ETA: 0s - loss: 0.5801 - acc: 0.9803 - dice_coef: 0.4195 - iou: 0.2923
# Epoch 2: saving model to files_mass_seg_xval\unet_mass_seg_v015_5.hdf5
# 423/423 [==============================] - 161s 380ms/step - loss: 0.5801 - acc: 0.9803 - dice_coef: 0.4195 - iou: 0.2923 - val_loss: nan - val_acc: 0.9812 - val_dice_coef: nan - val_iou: nan - lr: 1.0000e-04
# Epoch 3/100
# 423/423 [==============================] - ETA: 0s - loss: 0.5330 - acc: 0.9817 - dice_coef: 0.4666 - iou: 0.3336
# Epoch 3: saving model to files_mass_seg_xval\unet_mass_seg_v015_5.hdf5
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 423/423 [==============================] - 162s 382ms/step - loss: 0.5330 - acc: 0.9817 - dice_coef: 0.4666 - iou: 0.3336 - val_loss: nan - val_acc: 0.9821 - val_dice_coef: nan - val_iou: nan - lr: 1.0000e-04
# Epoch 4/100
# 423/423 [==============================] - ETA: 0s - loss: 0.4873 - acc: 0.9832 - dice_coef: 0.5133 - iou: 0.3810
# Epoch 4: saving model to files_mass_seg_xval\unet_mass_seg_v015_5.hdf5
# 423/423 [==============================] - 161s 379ms/step - loss: 0.4873 - acc: 0.9832 - dice_coef: 0.5133 - iou: 0.3810 - val_loss: nan - val_acc: 0.9824 - val_dice_coef: nan - val_iou: nan - lr: 1.0000e-05
# Epoch 5/100
# 423/423 [==============================] - ETA: 0s - loss: 0.4812 - acc: 0.9837 - dice_coef: 0.5184 - iou: 0.3875
# Epoch 5: saving model to files_mass_seg_xval\unet_mass_seg_v015_5.hdf5
# 423/423 [==============================] - 160s 378ms/step - loss: 0.4812 - acc: 0.9837 - dice_coef: 0.5184 - iou: 0.3875 - val_loss: nan - val_acc: 0.9832 - val_dice_coef: nan - val_iou: nan - lr: 1.0000e-05
# Epoch 5: early stopping

# %% [markdown]
# ### validate your model and save predicted results

# %%
validGene = testGenerator("mass_seg_08/valid0"+vid[-1]+"/pred",num_image=valid_count)
model.load_weights("files_mass_seg_xval/unet_mass_seg_"+vid+".hdf5")
results = model.predict(validGene,valid_count,verbose=1)
saveResult("mass_seg_08/valid0"+vid[-1]+"/pred",results,vid[:4])
# Out:
# 69/69 [==============================] - 19s 247ms/step
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\0_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\1_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\2_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\3_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\4_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\5_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\6_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\7_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\8_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\9_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\10_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\11_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\12_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\13_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\14_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\15_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\16_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\17_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\18_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\19_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\20_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\21_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\22_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\23_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\24_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\25_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\26_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\27_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\28_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\29_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\30_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\31_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\32_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\33_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\34_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\35_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\36_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\37_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\38_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\39_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\40_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\41_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\42_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\43_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\44_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\45_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\46_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\47_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\48_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\49_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\50_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\51_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\52_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\53_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\54_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\55_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\56_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\57_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\58_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\59_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\60_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\61_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\62_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\63_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\64_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\65_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\66_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img)
# D:\research\breastCancer\mass_seg\codes\data.py:110: UserWarning: mass_seg_08/valid05/pred\67_predict_v015.png is a low contrast image
#   io.imsave(os.path.join(save_path,"%d_predict_%s.png"%(i,vid)),img
['activation[0][0]']
#
#  activation_1 (Activation)      (None, 40, 40, 256)  0           ['batch_normalization_1[0][0]']
#
#  activation_2 (Activation)      (None, 40, 40, 256)  0           ['batch_normalization_2[0][0]']
#
#  activation_3 (Activation)      (None, 40, 40, 256)  0           ['batch_normalization_3[0][0]']
#
#  activation_4 (Activation)      (None, 40, 40, 256)  0           ['batch_normalization_4[0][0]']
#
#  concatenate (Concatenate)      (None, 40, 40, 1280  0           ['up_sampling2d[0][0]',
#                                 )                                 'activation_1[0][0]',
#                                                                   'activation_2[0][0]',
#                                                                   'activation_3[0][0]',
#                                                                   'activation_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 40, 40, 256)  327680      ['concatenate[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 40, 40, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  conv2d_6 (Conv2D)              (None, 160, 160, 48  12288       ['conv2_block2_out[0][0]']
#                                 )
#
#  activation_5 (Activation)      (None, 40, 40, 256)  0           ['batch_normalization_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 160, 160, 48  192        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  up_sampling2d_1 (UpSampling2D)  (None, 160, 160, 25  0          ['activation_5[0][0]']
#                                 6)
#
#  activation_6 (Activation)      (None, 160, 160, 48  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 160, 160, 30  0           ['up_sampling2d_1[0][0]',
#                                 4)                                'activation_6[0][0]']
#
#  global_average_pooling2d (Glob  (None, 304)         0           ['concatenate_1[0][0]']
#  alAveragePooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 304)    0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1, 1, 38)     11552       ['reshape[0][0]']
#
#  dense_1 (Dense)                (None, 1, 1, 304)    11552       ['dense[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 160, 160, 30  0           ['concatenate_1[0][0]',
#                                 4)                                'dense_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 160, 160, 25  700416      ['tf.math.multiply[0][0]']
#                                 6)
#
#  batch_normalization_7 (BatchNo  (None, 160, 160, 25  1024       ['conv2d_7[0][0]']
#  rmalization)                   6)
#
#  activation_7 (Activation)      (None, 160, 160, 25  0           ['batch_normalization_7[0][0]']
#                                 6)
#
#  conv2d_8 (Conv2D)              (None, 160, 160, 25  589824      ['activation_7[0][0]']
#                                 6)
#
#  batch_normalization_8 (BatchNo  (None, 160, 160, 25  1024       ['conv2d_8[0][0]']
#  rmalization)                   6)
#  activation_8 (Activation)      (None, 160, 160, 25  0           ['batch_normalization_8[0][0]']
#                                 6)
#
#  global_average_pooling2d_1 (Gl  (None, 256)         0           ['activation_8[0][0]']
#  obalAveragePooling2D)
#
#  reshape_1 (Reshape)            (None, 1, 1, 256)    0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_2 (Dense)                (None, 1, 1, 32)     8192        ['reshape_1[0][0]']
#
#  dense_3 (Dense)                (None, 1, 1, 256)    8192        ['dense_2[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 160, 160, 25  0          ['activation_8[0][0]',
#  )                              6)                                'dense_3[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 640, 640, 25  0          ['tf.math.multiply_1[0][0]']
#                                 6)
#
#  conv2d_9 (Conv2D)              (None, 640, 640, 1)  257         ['up_sampling2d_2[0][0]']
#
#  activation_9 (Activation)      (None, 640, 640, 1)  0           ['conv2d_9[0][0]']
#
# ==================================================================================================
# Total params: 17,869,697
# Trainable params: 17,834,913
# Non-trainable params: 34,784
# __________________________________________________________________________________________________
